# %% [markdown]
# # Exam 2 - Recap Exercises

# %% [markdown]
# <b>1.</b> Use subplots() method to create the plot as below:
# <br> a) Add title, xlabel, ylabel to each of axes
# <br> b) Add legend to figure
# <br> c) If needed use tight_layout()

# %%
# do not run this cell

# %% [markdown]
# <b>2. </b> You were given a tips dataset ready from seaborn
# <br> a) Show the distribution of the "total_bill" based on column "day"
# <br> b) Show the "tip" boxplot for every category in column "smoker"
# <br> c) Create a correlation matrix and show it in heatmap
# <br> d) Create a correlation matrix and show it in heatmap
# <br> f) For every plot, try to explain(read) the results

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# <b>3. </b> You were given a titanic dataset ready from seaborn
# <br> a) Create a new colums that show number of family members for each row
# <br> b) Countplot for number of family members
# <br> c) Using FacetGrid show distribution of age based on class
# <br> d) Create a correlation matrix and show it in heatmap
# <br> f) For every plot, try to explain(read) the results

# %%
titanic = sns.load_dataset('titanic')
titanic.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %% [markdown]
# <b>4. </b> You were given 911.csv dataset
# <br> - Count cases (plot) for every month in column "timeStamp". You may need to add new column with exctracted value of month.
# <br> - Add new column "Date" which extract the date part from timeStamp (use pd.to_datetime(x).date())
# <br> - Find the "Date" with the most cases (group by then max)
# <br> - Show the heatmap for (index='Date', column: 'count') //after group by with "Date" and finding the counts for "Date", use reset_index() and set_index('Date') to create matrix with index='Date'

# %% [markdown]
# <b>5. </b> You were given "all_banks" dataset
# <br> a) Find the difference of "High" and "Low" (High - Low) for each bank // you may need to use for loop or method .xs(key =, level = 1, axis = 1)
# <br> b) Show the maximum difference (from a)) for each bank, using barbplot
# <br> c) Show the maximum "Close" for each bank, using barbplot

# %%
import pandas as pd
banks = pd.read_pickle('all_banks')

# %% [markdown]
# <b>6.</b> We'll work with the Salaries csv file from the company. Linear Regression model will be used for prediction

# %%
import pandas as pd
salaries = pd.read_csv('salaries.csv')
salaries.head(2)
# Out:
#      EmpID   Name Surname Department  Age   Salary  Bonus  YearsAtCompany  \
# 0  EMP1000  Frank  Garcia  Marketing   59  93335.0  500.0               2
# 1  EMP1001  Alice   Jones    Finance   49  40965.0    NaN               1
#
#   PerformanceScore
# 0             Poor
# 1             Poor

# %% [markdown]
# <b>a)</b>
# - Convert performanceScore to numerical [0,1,2,3..]
# - Use pairplot to find potential relations beetween features salaries[['Age', 'Salary', 'Years..','Performance']]
# - Based on pairplot, which feature looks to be the most correlated feature with TotalPay

# %% [markdown]
# <b>b)</b> Data processing
# - Create a heat map for finding which feature has null values
# - Try to fill missing values (using average) or to drop columns (if it has more than 70% null values)
# - Drop columns with non-numerical values (except Department, you can drop it later)
# - Convert categorical values of "Department" column to numerical (you may use pd.get_dummies or do it manually)

# %% [markdown]
# <b>c)</b>
# - Create linear regression model for predicting "TotalPay"

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# <b>d)</b> Create a scatterplot of the real test values versus the predicted values.

# %% [markdown]
# <b>e)</b> Find evaluation metrics "MAE", "MSE" and "RMSE", comment the results from "MAE"

# %%
from sklearn import metrics

# %% [markdown]
# f) show coeficients on dataframe, which features had more impact on predicting

# %% [markdown]
# <b>7.</b> We'll work with the diabetes csv file. KNN clasifier model will be used for prediction
# - Exploratory data analysis
# - Data pre-processing (cleaning, standard scaler)
# - Train test split
# - Create model and use evaluation metrics for classification
# - Try different k-params, find which one gives best results
# - Interpret the results

# %%
diabetes = pd.read_csv('diabetes.csv')

# %% [markdown]
# <b>8. Theory question </b>
# <br> - General concepts of Machine Learning (ML) -flow (getting data, cleaning, train test ...), division (supervised-unsupervised), evaulation metrics, confussion matrix, regression and classification problems
# <br> - KNN, Linear Regression and Lasso
# <br> - Logistic Reg, Decision Tree, Random Forest
# <br> - Decision Tree - finding entropy and ig
