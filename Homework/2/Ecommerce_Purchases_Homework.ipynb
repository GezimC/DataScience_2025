# %% [markdown]
# # 🛒 Ecommerce Purchases Analysis – Homework

# %% [markdown]
# In this exercise, you'll work with a fictional dataset of ecommerce transactions.
# The data includes purchase prices, job titles, languages, browser info, and more.
# Your task is to explore, clean, analyze, and visualize this data using **Pandas** and **Matplotlib**.

# %% [markdown]
# ## 🔹 Part 1: Loading and Exploring the Data

# %% [markdown]
# 1. **Load the dataset** using Pandas and assign it to a variable named `ecom`.
#
# 2. Display the **first 5 rows** of the DataFrame.
#
# 3. How many **rows and columns** does the dataset contain?
#
# 4. Get a summary (`info`) of the DataFrame and identify any possible data quality issues.
#
# 5. What are the **column names**, and what are their respective data types?

# %% [markdown]
# ## 🔹 Part 2: Descriptive Statistics

# %% [markdown]
# 6. What is the **average Purchase Price**?
#
# 7. What are the **highest** and **lowest** purchase prices?
#
# 8. How many people made purchases during the **AM** and how many during the **PM**?
#
# 9. What are the **top 5 most common job titles**?
#
# 10. How many customers have their **language preference set to 'en'**?
#
# 11. How many people have the **job title of "Lawyer"**?

# %% [markdown]
# ## 🔹 Part 3: Specific Queries

# %% [markdown]
# 12. Find the **purchase price** for the transaction from **Lot "90 WT"**.
#
# 13. What is the **email** of the customer with the credit card number `4926535242672853`?
#
# 14. How many people use **American Express** and made a purchase above **$95**?
#
# 15. How many credit cards **expire in the year 2025**?
#
# 16. What are the **top 5 most common email providers** (e.g., gmail.com, yahoo.com)?

# %% [markdown]
# ## 🔹 Part 4: Data Manipulation & Filtering

# %% [markdown]
# 17. Create a new column called `Email Provider` by extracting the domain name from the `Email` column using `.apply()`.
#
# 18. Create a new column called `IsHighPurchase` which is `True` if `Purchase Price > 90` using `.apply()`.
#
# 19. Filter and display all rows where the `Job` contains the word `"engineer"` (case-insensitive).
#
# 20. Find out how many unique job titles exist.
#
# 21. Create a column `Card Expiry Year` using `.apply()` to extract the year part of `CC Exp Date`.
#
# 22. Create a column `Full Name` by rearranging the name from `"Last, First"` to `"First Last"` using `.apply()`.
#
# 23. Create a new column `Purchase Category` with values: 'Low' if < 50, 'Medium' if 50–90, 'High' if > 90 using a custom function with `.apply()`.

# %% [markdown]
# ## 🔹 Part 5: Data Visualization - Matplotlib Zoom Challenge

# %% [markdown]
# > ❓ **Task:**
# Use the `plt.figure()` and `add_axes()` method to:
#
# 1. Plot the function \( y = x^2 \) for \( x \) values from \(-10\) to \(10\).
#
# 2. Add a **smaller subplot inside** the main plot that:
#
#    - Zooms in to the area where \( x in [7, 10] \)
#
#
# 3. Add proper titles, axis labels, and make sure the mini-plot stands out.

# %%
# should be similar to this result
# Do not run this cell!!!!!

# %% [markdown]
# ## 🔹 Advanced Challenges

# %% [markdown]
# 29. Perform a **groupby** operation to get the **average purchase price by language**. Sort the result in descending order.
#
# 30. What is the **correlation** between `Purchase Price` and `Credit Card Expiry Month`?
#
# 31. Create a **line plot** showing the average purchase price **per credit card provider**.
#
# 32. Save your final DataFrame with additional columns (e.g. `Email Provider`, `IsHighPurchase`) to a new **CSV file**.

# %%
#expected result for question 31.   !!! Dont run this cell
# Group the data by credit card provider
# Calculate the average of the purchase price for each group
# Sort the results to make the plot more readable
# Create a line plot using the sorted results
# Don’t forget to label your axes and rotate the x-axis labels

# %% [markdown]
# ## 🔹 Bonus: Matplotlib Data Visualization (Special plots)

# %% [markdown]
# 1. Create a **bar chart** showing the **top 10 job titles**.
#
# 2. Plot a **pie chart** that shows the proportion of **purchases made in AM vs PM**.
#
# 3. Create a **histogram** of the `Purchase Price` column.
#
# 4. Plot a **bar chart** showing the **top 5 most used browsers** (extract from `Browser Info`).
#
# 5. Create a **boxplot** showing the distribution of `Purchase Price` per `Language`.
